# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %%
dataset=pd.read_csv("Placement_Data_Full_Class.csv")
dataset1=pd.read_csv("Placement_Data_Full_Class.csv")

# %%
dataset.shape
# Out:
# (217, 15)

# %%
dataset.head(50)
# Out:
#     sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0     1.0      M  67.00   Others  91.00   Others  Commerce     58.00
# 1     2.0      M  79.33  Central  78.33   Others   Science     77.48
# 2     3.0      M  65.00  Central  68.00  Central      Arts     64.00
# 3     4.0      M  56.00  Central  52.00  Central   Science     52.00
# 4     5.0      M  85.80  Central  73.60  Central  Commerce     73.30
# 5     6.0      M  55.00   Others  49.80   Others   Science     67.25
# 6     7.0      F  46.00   Others  49.20   Others  Commerce     79.00
# 7     NaN    NaN    NaN      NaN    NaN      NaN       NaN       NaN
# 8     NaN    NaN    NaN      NaN    NaN      NaN       NaN       NaN
# 9     8.0      M  82.00  Central  64.00  Central   Science     66.00
# 10    9.0      M  73.00  Central  79.00  Central  Commerce     72.00
# 11   10.0      M  58.00  Central  70.00  Central  Commerce     61.00
# 12   11.0      M  58.00  Central  61.00  Central  Commerce     60.00
# ...

# %%
dataset.dropna(how='all',inplace=True)        # Only if entire row is NaN [web:20]

# %%
dataset.shape
# Out:
# (215, 15)

# %%
dataset.head(15)
# Out:
#     sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0     1.0      M  67.00   Others  91.00   Others  Commerce     58.00
# 1     2.0      M  79.33  Central  78.33   Others   Science     77.48
# 2     3.0      M  65.00  Central  68.00  Central      Arts     64.00
# 3     4.0      M  56.00  Central  52.00  Central   Science     52.00
# 4     5.0      M  85.80  Central  73.60  Central  Commerce     73.30
# 5     6.0      M  55.00   Others  49.80   Others   Science     67.25
# 6     7.0      F  46.00   Others  49.20   Others  Commerce     79.00
# 9     8.0      M  82.00  Central  64.00  Central   Science     66.00
# 10    9.0      M  73.00  Central  79.00  Central  Commerce     72.00
# 11   10.0      M  58.00  Central  70.00  Central  Commerce     61.00
# 12   11.0      M  58.00  Central  61.00  Central  Commerce     60.00
# 13   12.0      M  69.60  Central  68.40  Central  Commerce     78.30
# 14   13.0      F  47.00  Central  55.00   Others   Science     65.00
# ...

# %%
dataset.isna().sum()
# Out:
# sl_no              0
# gender             0
# ssc_p              0
# ssc_b              0
# hsc_p              0
# hsc_b              0
# hsc_s              0
# degree_p           0
# degree_t           0
# workex             0
# etest_p            0
# specialisation     0
# mba_p              0
# status             0
# salary            67
# dtype: int64

# %%
dataset.isnull().sum()

# 2) as 67 students are nan values,so its value 67students are not placed,so nan values
# Out:
# sl_no              0
# gender             0
# ssc_p              0
# ssc_b              0
# hsc_p              0
# hsc_b              0
# hsc_s              0
# degree_p           0
# degree_t           0
# workex             0
# etest_p            0
# specialisation     0
# mba_p              0
# status             0
# salary            67
# dtype: int64

# %%
dataset["salary"].fillna(0,inplace=True)

# %%
dataset.isnull().sum()
# Out:
# sl_no             0
# gender            0
# ssc_p             0
# ssc_b             0
# hsc_p             0
# hsc_b             0
# hsc_s             0
# degree_p          0
# degree_t          0
# workex            0
# etest_p           0
# specialisation    0
# mba_p             0
# status            0
# salary            0
# dtype: int64

# %%
from Univ_Biv import UnivariateClass
Qual=[]
Quan=[]

# %%
UC=UnivariateClass()

# %%
Qual,Quan=UC.QualQuan(dataset)

# %%
Qual
# Out:
# ['gender',
#  'ssc_b',
#  'hsc_b',
#  'hsc_s',
#  'degree_t',
#  'workex',
#  'specialisation',
#  'status']

# %%
Quan
# Out:
# ['sl_no', 'ssc_p', 'hsc_p', 'degree_p', 'etest_p', 'mba_p', 'salary']

# %%
Quan.remove("sl_no")

# %%
Quan
# Out:
# ['ssc_p', 'hsc_p', 'degree_p', 'etest_p', 'mba_p', 'salary']

# %%
dataset.drop('sl_no',inplace=True,axis=1)

# %%
dataset
# Out:
#     gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p   degree_t  \
# 0        M  67.00   Others  91.00   Others  Commerce     58.00   Sci&Tech
# 1        M  79.33  Central  78.33   Others   Science     77.48   Sci&Tech
# 2        M  65.00  Central  68.00  Central      Arts     64.00  Comm&Mgmt
# 3        M  56.00  Central  52.00  Central   Science     52.00   Sci&Tech
# 4        M  85.80  Central  73.60  Central  Commerce     73.30  Comm&Mgmt
# ..     ...    ...      ...    ...      ...       ...       ...        ...
# 212      M  80.60   Others  82.00   Others  Commerce     77.60  Comm&Mgmt
# 213      M  58.00   Others  60.00   Others   Science     72.00   Sci&Tech
# 214      M  67.00   Others  67.00   Others  Commerce     73.00  Comm&Mgmt
# 215      F  74.00   Others  66.00   Others  Commerce     58.00  Comm&Mgmt
# 216      M  62.00  Central  58.00   Others   Science     53.00  Comm&Mgmt
#
#     workex  etest_p specialisation  mba_p      status    salary
# ...

# %%
dataset.shape
# Out:
# (215, 14)

# %%
dataset[Quan].describe()
# Out:
#             ssc_p       hsc_p    degree_p     etest_p       mba_p  \
# count  215.000000  215.000000  215.000000  215.000000  215.000000
# mean    67.303395   66.333163   66.370186   72.100558   62.278186
# std     10.827205   10.897509    7.358743   13.275956    5.833385
# min     40.890000   37.000000   50.000000   50.000000   51.210000
# 25%     60.600000   60.900000   61.000000   60.000000   57.945000
# 50%     67.000000   65.000000   66.000000   71.000000   62.000000
# 75%     75.700000   73.000000   72.000000   83.500000   66.255000
# max     89.400000   97.700000   91.000000   98.000000   77.890000
#
#               salary
# count     215.000000
# mean   198702.325581
# std    154780.926716
# min         0.000000
# 25%         0.000000
# 50%    240000.000000
# 75%    282500.000000
# max    940000.000000

# %%
dataset[Quan].describe()
# Out:
#             ssc_p       hsc_p    degree_p     etest_p       mba_p  \
# count  215.000000  215.000000  215.000000  215.000000  215.000000
# mean    67.303395   66.333163   66.370186   72.100558   62.278186
# std     10.827205   10.897509    7.358743   13.275956    5.833385
# min     40.890000   37.000000   50.000000   50.000000   51.210000
# 25%     60.600000   60.900000   61.000000   60.000000   57.945000
# 50%     67.000000   65.000000   66.000000   71.000000   62.000000
# 75%     75.700000   73.000000   72.000000   83.500000   66.255000
# max     89.400000   97.700000   91.000000   98.000000   77.890000
#
#               salary
# count     215.000000
# mean   198702.325581
# std    154780.926716
# min         0.000000
# 25%         0.000000
# 50%    240000.000000
# 75%    282500.000000
# max    940000.000000

# %%
dataset[Qual].describe()
# Out:
#        gender    ssc_b   hsc_b     hsc_s   degree_t workex specialisation  \
# count     215      215     215       215        215    215            215
# unique      2        2       2         3          3      2              2
# top         M  Central  Others  Commerce  Comm&Mgmt     No        Mkt&Fin
# freq      139      116     131       113        145    141            120
#
#         status
# count      215
# unique       2
# top     Placed
# freq       148

# %%
notplaced_salary = dataset[dataset['status'] == 'Not Placed']['salary']
print(notplaced_salary.describe())
# Out:
# count    67.0
# mean      0.0
# std       0.0
# min       0.0
# 25%       0.0
# 50%       0.0
# 75%       0.0
# max       0.0
# Name: salary, dtype: float64

# %%
(dataset[dataset['status']=='Not Placed'][Quan]).describe()
# Out:
#            ssc_p      hsc_p   degree_p    etest_p      mba_p  salary
# count  67.000000  67.000000  67.000000  67.000000  67.000000    67.0
# mean   57.544030  58.395522  61.134179  69.587910  61.612836     0.0
# std     8.394246   9.914090   6.365825  11.930687   5.705689     0.0
# min    40.890000  37.000000  50.000000  50.000000  51.210000     0.0
# 25%    52.000000  51.000000  57.000000  60.000000  58.480000     0.0
# 50%    56.280000  60.330000  61.000000  67.000000  60.690000     0.0
# 75%    63.000000  64.000000  65.000000  76.500000  65.405000     0.0
# max    77.800000  82.000000  79.000000  97.000000  75.710000     0.0

# %%
(dataset[dataset['status']=='Not Placed'][Qual]).describe()
# Out:
#        gender    ssc_b   hsc_b     hsc_s   degree_t workex specialisation  \
# count      67       67      67        67         67     67             67
# unique      2        2       2         3          3      2              2
# top         M  Central  Others  Commerce  Comm&Mgmt     No         Mkt&HR
# freq       39       38      40        34         43     57             42
#
#             status
# count           67
# unique           1
# top     Not Placed
# freq            67

# %%
dataset[dataset['salary']>500000][Quan].count
# Out:
# <bound method DataFrame.count of      ssc_p  hsc_p  degree_p  etest_p  mba_p    salary
# 121   60.8  68.40      64.6    82.66  64.34  940000.0
# 152   71.0  58.66      58.0    56.00  61.30  690000.0
# 179   73.0  97.00      79.0    89.00  70.81  650000.0>

# %%
dataset[dataset['salary']>500000][Qual].count
# Out:
# <bound method DataFrame.count of     gender    ssc_b    hsc_b     hsc_s   degree_t workex specialisation  \
# 121      M  Central  Central  Commerce  Comm&Mgmt    Yes        Mkt&Fin
# 152      M  Central  Central   Science   Sci&Tech    Yes        Mkt&Fin
# 179      F  Central   Others  Commerce  Comm&Mgmt    Yes        Mkt&Fin
#
#      status
# 121  Placed
# 152  Placed
# 179  Placed  >

# %%
dataset1['salary'].min()
# Out:
# 200000.0

# %%
dataset[dataset['salary']==200000][Qual]
# Out:
#     gender    ssc_b    hsc_b     hsc_s   degree_t workex specialisation  \
# 1        M  Central   Others   Science   Sci&Tech    Yes        Mkt&Fin
# 17       F  Central  Central  Commerce  Comm&Mgmt    Yes        Mkt&Fin
# 46       F   Others   Others  Commerce  Comm&Mgmt    Yes        Mkt&Fin
# 52       F  Central  Central   Science  Comm&Mgmt     No         Mkt&HR
# 109      M   Others   Others  Commerce  Comm&Mgmt     No         Mkt&HR
# 137      F  Central   Others   Science  Comm&Mgmt     No         Mkt&HR
#
#      status
# 1    Placed
# 17   Placed
# 46   Placed
# 52   Placed
# 109  Placed
# 137  Placed

# %%
#4) Relation between mba_p and salary 13.9% increasing
    #The Corr(mba_p,salary) is 0.1398823,that is 13.9%,Low degree of Positive Correlation,
    #   if mba_p increases then salary will be 13.9% of increase

dataset[Quan].corr()
# Out:
#              ssc_p     hsc_p  degree_p   etest_p     mba_p    salary
# ssc_p     1.000000  0.511472  0.538404  0.261993  0.388478  0.538090
# hsc_p     0.511472  1.000000  0.434206  0.245113  0.354823  0.452569
# degree_p  0.538404  0.434206  1.000000  0.224470  0.402364  0.408371
# etest_p   0.261993  0.245113  0.224470  1.000000  0.218055  0.186988
# mba_p     0.388478  0.354823  0.402364  0.218055  1.000000  0.139823
# salary    0.538090  0.452569  0.408371  0.186988  0.139823  1.000000

# %%
# def check_OutlierColumns(descriptive,quan)

# %%
lesser=[]

# %%
greater=[]

# %%
dataset[Quan].describe()
# Out:
#             ssc_p       hsc_p    degree_p     etest_p       mba_p  \
# count  215.000000  215.000000  215.000000  215.000000  215.000000
# mean    67.303395   66.333163   66.370186   72.100558   62.278186
# std     10.827205   10.897509    7.358743   13.275956    5.833385
# min     40.890000   37.000000   50.000000   50.000000   51.210000
# 25%     60.600000   60.900000   61.000000   60.000000   57.945000
# 50%     67.000000   65.000000   66.000000   71.000000   62.000000
# 75%     75.700000   73.000000   72.000000   83.500000   66.255000
# max     89.400000   97.700000   91.000000   98.000000   77.890000
#
#               salary
# count     215.000000
# mean   198702.325581
# std    154780.926716
# min         0.000000
# 25%         0.000000
# 50%    240000.000000
# 75%    282500.000000
# max    940000.000000

# %%
descriptive=UC.Univariate_Table(dataset,Quan)

lesser=[]
greater=[]

lesser,greater=UC.check_OutlierColumns(descriptive,Quan)

# %%
UC.replace_Outlier(dataset,descriptive,lesser,greater)

# %%
# 7) Analysis of Variance

# H0 :There is no significant difference of 5% between etest_p and mba_p
# H1 :There is significant difference of 5% between etest_p and mba_p

# %%
import scipy.stats as stats
stats.f_oneway(dataset['etest_p'],dataset['mba_p'])
# Out:
# F_onewayResult(statistic=98.64487057324709, pvalue=4.672547689133636e-21)

# %%
# As p value < 0.05 ie ( 5 % ) then accept H1, H1 :There is significant difference of 5% between etest_p and mba_p

# %%
# 8) Test the similarity between the degree_t(Sci&Tech) and specialisation(Mkt&HR) with respect to salary at significance level of 5%.(Make
#    decision using Hypothesis Testing)

# H0 :There is no similarity between degree_t(Sci&Tech) and specialisation(Mkt&HR) with respect to salary at 5%
# H1 :There is similarity between degree_t(Sci&Tech) and specialisation(Mkt&HR) with respect to salary at 5%

# %%
from scipy.stats import ttest_ind
dataset=dataset.dropna()
SciTech=dataset[dataset['degree_t']=='Sci&Tech']['salary']
MktHR=dataset[dataset['specialisation']=='Mkt&HR']['salary']
ttest_ind(SciTech,MktHR)
# Out:
# TtestResult(statistic=2.692041243555374, pvalue=0.007897969943471191, df=152.0)

# %%
# As p < 0.05 ,accept H1, H1 :There is similarity between degree_t(Sci&Tech) and specialisation(Mkt&HR) with respect to salary at 5%

# %%
# 9) Convert the normal distribution to standard normal distribution for
#    salary column

# %%
def stdNBgraph(dataset):
        # Coverted to standard Normal Distribution
    import seaborn as sns
    mean=dataset.mean()
    std=dataset.std()

    values=[i for i in dataset]

    z_score=[((j-mean)/std) for j in values]

    sns.distplot(z_score,kde=True)

    sum(z_score)/len(z_score)
    #z_score.std()

# %%
stdNBgraph(dataset['salary'])

# %%
#  10)What is the probability Density Function of the salary range from
#     700000 to 900000?

# %%
def get_pdf_probability(dataset,startrange,endrange):
    from matplotlib import pyplot
    from scipy.stats import norm
    import seaborn as sns
    ax = sns.distplot(dataset,kde=True,kde_kws={'color':'blue'},color='Green')
    pyplot.axvline(startrange,color='Red')
    pyplot.axvline(endrange,color='Red')
    # generate a sample
    sample = dataset
    # calculate parameters
    sample_mean =sample.mean()
    sample_std = sample.std()
    print('Mean=%.3f, Standard Deviation=%.3f' % (sample_mean, sample_std))
    # define the distribution
    dist = norm(sample_mean, sample_std)
    
    # sample probabilities for a range of outcomes
    values = [value for value in range(startrange, endrange)]
    probabilities = [dist.pdf(value) for value in values]    
    prob=sum(probabilities)
    print("The area between range({},{}):{}".format(startrange,endrange,sum(probabilities)))
    return prob

# %%
get_pdf_probability(dataset['salary'],700000,900000)
# Out:
# Mean=198702.326, Standard Deviation=154780.927
# The area between range(700000,900000):0.0005973310593974868
# 0.0005973310593974868

# %%
#  11)Test the similarity between the degree_t(Sci&Tech)with respect to etest_p and mba_p at significance level of 5%.
#     (Make decision using Hypothesis Testing)

# H0 :There is no similarity between the degree_t(Sci&Tech)with respect to etest_p and mba_p at significance level of 5%
# H1 :There is similarity between the degree_t(Sci&Tech)with respect to etest_p and mba_p at significance level of 5%

# %%
from scipy.stats import ttest_rel
dataset=dataset.dropna()
SciTech1=dataset[dataset['degree_t']=='Sci&Tech']['etest_p']
SciTech2=dataset[dataset['degree_t']=='Sci&Tech']['mba_p']
ttest_rel(SciTech1,SciTech2)
# Out:
# TtestResult(statistic=5.0049844583693615, pvalue=5.5179206005054e-06, df=58)

# %%
# As p < 0.05, accept H1, There is similarity between the degree_t(Sci&Tech)with respect to etest_p and mba_p at significance level of 5%

# %%
# 12) Which parameter is highly correlated with salary?

# %%
import seaborn as sns
sns.pairplot(dataset,hue='gender')

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

def calc_vif(X): # must give only Quan data
    vif = pd.DataFrame()
    vif["variables"] = X.columns
    vif["VIF"] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
    return vif

# %%
# calc_vif(dataset[["etest_p","salary"]])
calc_vif(dataset[Quan])
# Out:
#   variables         VIF
# 0     ssc_p   76.496603
# 1     hsc_p   58.972066
# 2  degree_p  113.299298
# 3   etest_p   32.679659
# 4     mba_p  114.025972
# 5    salary    3.931112

# %%
calc_vif(dataset[["ssc_p","salary"]]) # between 1 & 5 moderately correlated
# Out:
#   variables       VIF
# 0     ssc_p  3.248087
# 1    salary  3.248087

# %%
calc_vif(dataset[["hsc_p","salary"]])
# Out:
#   variables       VIF
# 0     hsc_p  3.116876
# 1    salary  3.116876

# %%
calc_vif(dataset[["degree_p","salary"]])
# Out:
#   variables       VIF
# 0  degree_p  2.940539
# 1    salary  2.940539

# %%
calc_vif(dataset[["etest_p","salary"]])
# Out:
#   variables       VIF
# 0   etest_p  2.745261
# 1    salary  2.745261

# %%
calc_vif(dataset[["mba_p","salary"]])
# Out:
#   variables       VIF
# 0     mba_p  2.707661
# 1    salary  2.707661

# %%
# 13) plot any useful graph and explain it.

#sns.violinplot(x='ssc_b',y='salary')
sns.histplot(x=dataset['mba_p'],kde=True)
# Out:
# <Axes: xlabel='mba_p', ylabel='Count'>

# %%
import matplotlib.pyplot as plt
sns.boxplot(x='gender',y='ssc_p',data=dataset)
plt.show()
