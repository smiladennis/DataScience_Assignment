# %%
import pandas as pd
import warnings
warnings.filterwarnings("ignore")

# %%
dataset=pd.read_csv("Placement_Data_Full_Class.csv")
dataset1=pd.read_csv("Placement_Data_Full_Class.csv")

# %%
dataset
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0      1.0      M  67.00   Others  91.00   Others  Commerce     58.00
# 1      2.0      M  79.33  Central  78.33   Others   Science     77.48
# 2      3.0      M  65.00  Central  68.00  Central      Arts     64.00
# 3      4.0      M  56.00  Central  52.00  Central   Science     52.00
# 4      5.0      M  85.80  Central  73.60  Central  Commerce     73.30
# ..     ...    ...    ...      ...    ...      ...       ...       ...
# 212  211.0      M  80.60   Others  82.00   Others  Commerce     77.60
# 213  212.0      M  58.00   Others  60.00   Others   Science     72.00
# 214  213.0      M  67.00   Others  67.00   Others  Commerce     73.00
# 215  214.0      F  74.00   Others  66.00   Others  Commerce     58.00
# 216  215.0      M  62.00  Central  58.00   Others   Science     53.00
#
#       degree_t workex  etest_p specialisation  mba_p      status    salary
# ...

# %%
dataset.isna().sum()
# Out:
# sl_no              2
# gender             2
# ssc_p              2
# ssc_b              2
# hsc_p              2
# hsc_b              2
# hsc_s              2
# degree_p           2
# degree_t           2
# workex             2
# etest_p            2
# specialisation     2
# mba_p              2
# status             2
# salary            69
# dtype: int64

# %%
dataset.head(10)
# Out:
#    sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0    1.0      M  67.00   Others  91.00   Others  Commerce     58.00
# 1    2.0      M  79.33  Central  78.33   Others   Science     77.48
# 2    3.0      M  65.00  Central  68.00  Central      Arts     64.00
# 3    4.0      M  56.00  Central  52.00  Central   Science     52.00
# 4    5.0      M  85.80  Central  73.60  Central  Commerce     73.30
# 5    6.0      M  55.00   Others  49.80   Others   Science     67.25
# 6    7.0      F  46.00   Others  49.20   Others  Commerce     79.00
# 7    NaN    NaN    NaN      NaN    NaN      NaN       NaN       NaN
# 8    NaN    NaN    NaN      NaN    NaN      NaN       NaN       NaN
# 9    8.0      M  82.00  Central  64.00  Central   Science     66.00
#
#     degree_t workex  etest_p specialisation  mba_p      status    salary
# 0   Sci&Tech     No    55.00         Mkt&HR  58.80      Placed  270000.0
# 1   Sci&Tech    Yes    86.50        Mkt&Fin  66.28      Placed  200000.0
# ...

# %%
#  2)  69 students have nan values ,so they are not placed

# %%
dataset.isnull().sum()
# Out:
# sl_no              2
# gender             2
# ssc_p              2
# ssc_b              2
# hsc_p              2
# hsc_b              2
# hsc_s              2
# degree_p           2
# degree_t           2
# workex             2
# etest_p            2
# specialisation     2
# mba_p              2
# status             2
# salary            69
# dtype: int64

# %%
dataset.isna().sum()
# Out:
# sl_no              2
# gender             2
# ssc_p              2
# ssc_b              2
# hsc_p              2
# hsc_b              2
# hsc_s              2
# degree_p           2
# degree_t           2
# workex             2
# etest_p            2
# specialisation     2
# mba_p              2
# status             2
# salary            69
# dtype: int64

# %%
dataset["salary"].fillna(0,inplace=True)

# %%
dataset.isna().sum()
# Out:
# sl_no             2
# gender            2
# ssc_p             2
# ssc_b             2
# hsc_p             2
# hsc_b             2
# hsc_s             2
# degree_p          2
# degree_t          2
# workex            2
# etest_p           2
# specialisation    2
# mba_p             2
# status            2
# salary            0
# dtype: int64

# %%
from Univ_Biv import UnivariateClass
Qual=[]
Quan=[]

# %%
Qual,Quan=UnivariateClass.QualQuan(dataset)

# %%
Qual
# Out:
# ['gender',
#  'ssc_b',
#  'hsc_b',
#  'hsc_s',
#  'degree_t',
#  'workex',
#  'specialisation',
#  'status']

# %%
Quan
# Out:
# ['sl_no', 'ssc_p', 'hsc_p', 'degree_p', 'etest_p', 'mba_p', 'salary']

# %%
Quan.remove('sl_no')

# %%
Quan
# Out:
# ['ssc_p', 'hsc_p', 'degree_p', 'etest_p', 'mba_p', 'salary']

# %%
dataset.drop('sl_no',inplace=True,axis=1)

# %%
dataset.head(20)
# Out:
#    gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p   degree_t  \
# 0       M  67.00   Others  91.00   Others  Commerce     58.00   Sci&Tech
# 1       M  79.33  Central  78.33   Others   Science     77.48   Sci&Tech
# 2       M  65.00  Central  68.00  Central      Arts     64.00  Comm&Mgmt
# 3       M  56.00  Central  52.00  Central   Science     52.00   Sci&Tech
# 4       M  85.80  Central  73.60  Central  Commerce     73.30  Comm&Mgmt
# 5       M  55.00   Others  49.80   Others   Science     67.25   Sci&Tech
# 6       F  46.00   Others  49.20   Others  Commerce     79.00  Comm&Mgmt
# 7       M    NaN  Central    NaN   Others  Commerce       NaN  Comm&Mgmt
# 8       M    NaN  Central    NaN   Others  Commerce       NaN  Comm&Mgmt
# 9       M  82.00  Central  64.00  Central   Science     66.00   Sci&Tech
# 10      M  73.00  Central  79.00  Central  Commerce     72.00  Comm&Mgmt
# 11      M  58.00  Central  70.00  Central  Commerce     61.00  Comm&Mgmt
# ...

# %%
dataset[Quan]
# Out:
#      ssc_p  hsc_p  degree_p  etest_p  mba_p    salary
# 0    67.00  91.00     58.00     55.0  58.80  270000.0
# 1    79.33  78.33     77.48     86.5  66.28  200000.0
# 2    65.00  68.00     64.00     75.0  57.80  250000.0
# 3    56.00  52.00     52.00     66.0  59.43       0.0
# 4    85.80  73.60     73.30     96.8  55.50  425000.0
# ..     ...    ...       ...      ...    ...       ...
# 212  80.60  82.00     77.60     91.0  74.49  400000.0
# 213  58.00  60.00     72.00     74.0  53.62  275000.0
# 214  67.00  67.00     73.00     59.0  69.72  295000.0
# 215  74.00  66.00     58.00     70.0  60.23  204000.0
# 216  62.00  58.00     53.00     89.0  60.22       0.0
#
# [217 rows x 6 columns]

# %%
dataset[Quan].isna().sum()
# Out:
# ssc_p       2
# hsc_p       2
# degree_p    2
# etest_p     2
# mba_p       2
# salary      0
# dtype: int64

# %%
dataset.describe()
# Out:
#             ssc_p       hsc_p    degree_p     etest_p       mba_p  \
# count  215.000000  215.000000  215.000000  215.000000  215.000000
# mean    67.303395   66.333163   66.370186   72.100558   62.278186
# std     10.827205   10.897509    7.358743   13.275956    5.833385
# min     40.890000   37.000000   50.000000   50.000000   51.210000
# 25%     60.600000   60.900000   61.000000   60.000000   57.945000
# 50%     67.000000   65.000000   66.000000   71.000000   62.000000
# 75%     75.700000   73.000000   72.000000   83.500000   66.255000
# max     89.400000   97.700000   91.000000   98.000000   77.890000
#
#               salary
# count     217.000000
# mean   196870.967742
# std    155233.760215
# min         0.000000
# 25%         0.000000
# 50%    240000.000000
# 75%    280000.000000
# max    940000.000000

# %%
dataset[Qual]
# Out:
#     gender    ssc_b    hsc_b     hsc_s   degree_t workex specialisation  \
# 0        M   Others   Others  Commerce   Sci&Tech     No         Mkt&HR
# 1        M  Central   Others   Science   Sci&Tech    Yes        Mkt&Fin
# 2        M  Central  Central      Arts  Comm&Mgmt     No        Mkt&Fin
# 3        M  Central  Central   Science   Sci&Tech     No         Mkt&HR
# 4        M  Central  Central  Commerce  Comm&Mgmt     No        Mkt&Fin
# ..     ...      ...      ...       ...        ...    ...            ...
# 212      M   Others   Others  Commerce  Comm&Mgmt     No        Mkt&Fin
# 213      M   Others   Others   Science   Sci&Tech     No        Mkt&Fin
# 214      M   Others   Others  Commerce  Comm&Mgmt    Yes        Mkt&Fin
# 215      F   Others   Others  Commerce  Comm&Mgmt     No         Mkt&HR
# 216      M  Central   Others   Science  Comm&Mgmt     No         Mkt&HR
#
#          status
# 0        Placed
# 1        Placed
# 2        Placed
# 3    Not Placed
# ...

# %%
dataset[Qual].isna().sum()
# Out:
# gender            2
# ssc_b             2
# hsc_b             2
# hsc_s             2
# degree_t          2
# workex            2
# specialisation    2
# status            2
# dtype: int64

# %%
import numpy as np
from sklearn.impute import SimpleImputer
num_imp = SimpleImputer(missing_values=np.nan, strategy='median')
num_imp.fit(dataset[Quan])
num_df=num_imp.transform(dataset[Quan])
num_df = pd.DataFrame(num_df,columns = Quan)
new_dataset=num_df.copy()

# %%
new_dataset
# Out:
#      ssc_p  hsc_p  degree_p  etest_p  mba_p    salary
# 0    67.00  91.00     58.00     55.0  58.80  270000.0
# 1    79.33  78.33     77.48     86.5  66.28  200000.0
# 2    65.00  68.00     64.00     75.0  57.80  250000.0
# 3    56.00  52.00     52.00     66.0  59.43       0.0
# 4    85.80  73.60     73.30     96.8  55.50  425000.0
# ..     ...    ...       ...      ...    ...       ...
# 212  80.60  82.00     77.60     91.0  74.49  400000.0
# 213  58.00  60.00     72.00     74.0  53.62  275000.0
# 214  67.00  67.00     73.00     59.0  69.72  295000.0
# 215  74.00  66.00     58.00     70.0  60.23  204000.0
# 216  62.00  58.00     53.00     89.0  60.22       0.0
#
# [217 rows x 6 columns]

# %%
new_dataset.isna().sum()
# Out:
# ssc_p       0
# hsc_p       0
# degree_p    0
# etest_p     0
# mba_p       0
# salary      0
# dtype: int64

# %%
dataset[Qual].isna().sum()
# Out:
# gender            2
# ssc_b             2
# hsc_b             2
# hsc_s             2
# degree_t          2
# workex            2
# specialisation    2
# status            2
# dtype: int64

# %%
dataset[Qual]
# Out:
#     gender    ssc_b    hsc_b     hsc_s   degree_t workex specialisation  \
# 0        M   Others   Others  Commerce   Sci&Tech     No         Mkt&HR
# 1        M  Central   Others   Science   Sci&Tech    Yes        Mkt&Fin
# 2        M  Central  Central      Arts  Comm&Mgmt     No        Mkt&Fin
# 3        M  Central  Central   Science   Sci&Tech     No         Mkt&HR
# 4        M  Central  Central  Commerce  Comm&Mgmt     No        Mkt&Fin
# ..     ...      ...      ...       ...        ...    ...            ...
# 212      M   Others   Others  Commerce  Comm&Mgmt     No        Mkt&Fin
# 213      M   Others   Others   Science   Sci&Tech     No        Mkt&Fin
# 214      M   Others   Others  Commerce  Comm&Mgmt    Yes        Mkt&Fin
# 215      F   Others   Others  Commerce  Comm&Mgmt     No         Mkt&HR
# 216      M  Central   Others   Science  Comm&Mgmt     No         Mkt&HR
#
#          status
# 0        Placed
# 1        Placed
# 2        Placed
# 3    Not Placed
# ...

# %%
qual_imp = SimpleImputer(strategy='most_frequent')
dataset[Qual] = pd.DataFrame(qual_imp.fit_transform(dataset[Qual]), 
                           columns=Qual, 
                           index=dataset.index)

# %%
dataset[Qual].isna().sum()
# Out:
# gender            0
# ssc_b             0
# hsc_b             0
# hsc_s             0
# degree_t          0
# workex            0
# specialisation    0
# status            0
# dtype: int64

# %%
dataQualQuan=new_dataset[Quan].join(dataset[Qual])

# %%
dataQualQuan.isna().sum()
# Out:
# ssc_p             0
# hsc_p             0
# degree_p          0
# etest_p           0
# mba_p             0
# salary            0
# gender            0
# ssc_b             0
# hsc_b             0
# hsc_s             0
# degree_t          0
# workex            0
# specialisation    0
# status            0
# dtype: int64

# %%
# 1)

dataQualQuan
# Out:
#      ssc_p  hsc_p  degree_p  etest_p  mba_p    salary gender    ssc_b  \
# 0    67.00  91.00     58.00     55.0  58.80  270000.0      M   Others
# 1    79.33  78.33     77.48     86.5  66.28  200000.0      M  Central
# 2    65.00  68.00     64.00     75.0  57.80  250000.0      M  Central
# 3    56.00  52.00     52.00     66.0  59.43       0.0      M  Central
# 4    85.80  73.60     73.30     96.8  55.50  425000.0      M  Central
# ..     ...    ...       ...      ...    ...       ...    ...      ...
# 212  80.60  82.00     77.60     91.0  74.49  400000.0      M   Others
# 213  58.00  60.00     72.00     74.0  53.62  275000.0      M   Others
# 214  67.00  67.00     73.00     59.0  69.72  295000.0      M   Others
# 215  74.00  66.00     58.00     70.0  60.23  204000.0      F   Others
# 216  62.00  58.00     53.00     89.0  60.22       0.0      M  Central
#
#        hsc_b     hsc_s   degree_t workex specialisation      status
# ...

# %%
dir (dataset)
# Out:
# ['T',
#  '_AXIS_LEN',
#  '_AXIS_ORDERS',
#  '_AXIS_TO_AXIS_NUMBER',
#  '_HANDLED_TYPES',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__annotations__',
#  '__array__',
#  '__array_priority__',
#  '__array_ufunc__',
#  '__arrow_c_stream__',
#  '__bool__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__dataframe__',
#  '__dataframe_consortium_standard__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__ifloordiv__',
#  '__imod__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__invert__',
#  '__ior__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__matmul__',
#  '__mod__',
#  '__module__',
# ...

# %%
#4) Relation between mba_p and salary 13% increasing
    #The Corr(mba_p,salary) is 0.1398823,that is 13%,Low degree of Positive Correlation,
    #   if mba_p increases then salary will be 13% of increase

dataset[Quan].corr()
# Out:
#              ssc_p     hsc_p  degree_p   etest_p     mba_p    salary
# ssc_p     1.000000  0.511472  0.538404  0.261993  0.388478  0.538090
# hsc_p     0.511472  1.000000  0.434206  0.245113  0.354823  0.452569
# degree_p  0.538404  0.434206  1.000000  0.224470  0.402364  0.408371
# etest_p   0.261993  0.245113  0.224470  1.000000  0.218055  0.186988
# mba_p     0.388478  0.354823  0.402364  0.218055  1.000000  0.139823
# salary    0.538090  0.452569  0.408371  0.186988  0.139823  1.000000

# %%
dataset[Quan].describe()
# Out:
#             ssc_p       hsc_p    degree_p     etest_p       mba_p  \
# count  215.000000  215.000000  215.000000  215.000000  215.000000
# mean    67.303395   66.333163   66.370186   72.100558   62.278186
# std     10.827205   10.897509    7.358743   13.275956    5.833385
# min     40.890000   37.000000   50.000000   50.000000   51.210000
# 25%     60.600000   60.900000   61.000000   60.000000   57.945000
# 50%     67.000000   65.000000   66.000000   71.000000   62.000000
# 75%     75.700000   73.000000   72.000000   83.500000   66.255000
# max     89.400000   97.700000   91.000000   98.000000   77.890000
#
#               salary
# count     217.000000
# mean   196870.967742
# std    155233.760215
# min         0.000000
# 25%         0.000000
# 50%    240000.000000
# 75%    280000.000000
# max    940000.000000

# %%
#2) Not Placed ?
notplaced_salary = dataset[dataset['status'] == 'Not Placed']['salary']
print(notplaced_salary.describe())

(dataset[dataset['status']=='Not Placed'][Quan]).describe()
# Out:
# count    67.0
# mean      0.0
# std       0.0
# min       0.0
# 25%       0.0
# 50%       0.0
# 75%       0.0
# max       0.0
# Name: salary, dtype: float64
#            ssc_p      hsc_p   degree_p    etest_p      mba_p  salary
# count  67.000000  67.000000  67.000000  67.000000  67.000000    67.0
# mean   57.544030  58.395522  61.134179  69.587910  61.612836     0.0
# std     8.394246   9.914090   6.365825  11.930687   5.705689     0.0
# min    40.890000  37.000000  50.000000  50.000000  51.210000     0.0
# 25%    52.000000  51.000000  57.000000  60.000000  58.480000     0.0
# 50%    56.280000  60.330000  61.000000  67.000000  60.690000     0.0
# 75%    63.000000  64.000000  65.000000  76.500000  65.405000     0.0
# max    77.800000  82.000000  79.000000  97.000000  75.710000     0.0

# %%
#67 not placed

# %%
#3) Reason for non_Placement from dataset
'''because of no work_experience 57
                specialisation  Mkt&HR 42
                hsc_b  Others 40
                gender M 39
                ssc_b Central 38


'''

# %%
(dataset[dataset['status']=='Not Placed'][Qual]).describe()
# Out:
#        gender    ssc_b   hsc_b     hsc_s   degree_t workex specialisation  \
# count      67       67      67        67         67     67             67
# unique      2        2       2         3          3      2              2
# top         M  Central  Others  Commerce  Comm&Mgmt     No         Mkt&HR
# freq       39       38      40        34         43     57             42
#
#             status
# count           67
# unique           1
# top     Not Placed
# freq            67

# %%
# 5)Which specialisation getting minimum salary
#Mkt & HR,Mkt & Fin
dataset1.describe()
# Out:
#             sl_no       ssc_p       hsc_p    degree_p     etest_p       mba_p  \
# count  215.000000  215.000000  215.000000  215.000000  215.000000  215.000000
# mean   108.000000   67.303395   66.333163   66.370186   72.100558   62.278186
# std     62.209324   10.827205   10.897509    7.358743   13.275956    5.833385
# min      1.000000   40.890000   37.000000   50.000000   50.000000   51.210000
# 25%     54.500000   60.600000   60.900000   61.000000   60.000000   57.945000
# 50%    108.000000   67.000000   65.000000   66.000000   71.000000   62.000000
# 75%    161.500000   75.700000   73.000000   72.000000   83.500000   66.255000
# max    215.000000   89.400000   97.700000   91.000000   98.000000   77.890000
#
#               salary
# count     148.000000
# mean   288655.405405
# std     93457.452420
# min    200000.000000
# 25%    240000.000000
# 50%    265000.000000
# 75%    300000.000000
# max    940000.000000

# %%
dataset1[Qual].describe()
# Out:
#        gender    ssc_b   hsc_b     hsc_s   degree_t workex specialisation  \
# count     215      215     215       215        215    215            215
# unique      2        2       2         3          3      2              2
# top         M  Central  Others  Commerce  Comm&Mgmt     No        Mkt&Fin
# freq      139      116     131       113        145    141            120
#
#         status
# count      215
# unique       2
# top     Placed
# freq       148

# %%
# 6)How many of them getting above 500000 salary?
# about 6 of them salary>= 500000

# %%
# 7)Co_Variance

# %%
dataset[Quan].cov()
# Out:
#                   ssc_p          hsc_p       degree_p        etest_p  \
# ssc_p        117.228377      60.348373      42.897137      37.659225
# hsc_p         60.348373     118.755706      34.819820      35.461678
# degree_p      42.897137      34.819820      54.151103      21.929469
# etest_p       37.659225      35.461678      21.929469     176.251018
# mba_p         24.535952      22.555846      17.272020      16.886973
# salary    901754.893936  763359.777657  465131.504238  384234.419257
#
#                   mba_p        salary
# ssc_p         24.535952  9.017549e+05
# hsc_p         22.555846  7.633598e+05
# degree_p      17.272020  4.651315e+05
# etest_p       16.886973  3.842344e+05
# mba_p         34.028376  1.262455e+05
# salary    126245.485547  2.409752e+10

# %%
# The difference between etest_p and mba_p is is 16.88%,which is positive Co_variance 
# Anavo Test

# %%
import scipy.stats as stats
stats.f_oneway(dataQualQuan['etest_p'],dataQualQuan['mba_p'])
# Out:
# F_onewayResult(statistic=100.33226296639643, pvalue=2.2444909488517615e-21)

# %%
#Hypothesis Testing

#H0:There is no significant difference between etest_p and mba_p
#H1:There is significant difference between etest_p and mba_p

As p
# Out:
#   Cell In[47], line 6
#     As p
#        ^
# SyntaxError: invalid syntax

# %%
import statsmodels.api as sm
from statsmodels.formula.api import ols

#perform two-way ANOVA
model = ols('degree_p ~ ssc_p + hsc_p + ssc_p:hsc_p', data=dataset).fit()
sm.stats.anova_lm(model, typ=2)
